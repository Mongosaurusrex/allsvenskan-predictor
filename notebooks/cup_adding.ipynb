# %%
import polars as pl

# load dataset
df = pl.read_csv("../data/01_raw/swedish_leagues_2011_2025_clean.csv")

# add competition column
df = df.with_columns(
    pl.lit("league").alias("competition")
)

# save back
df.write_csv("../data/01_raw/swedish_leagues_2011_2025_clean.csv")

print(df.head())
# Out:
# shape: (5, 10)
# ┌────────────┬─────────────┬────────────┬────────────┬───┬────────┬──────────┬────────┬────────────┐
# │ date       ┆ home_team   ┆ away_team  ┆ home_goals ┆ … ┆ season ┆ matchday ┆ result ┆ competitio │
# │ ---        ┆ ---         ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---      ┆ ---    ┆ n          │
# │ str        ┆ str         ┆ str        ┆ i64        ┆   ┆ i64    ┆ i64      ┆ str    ┆ ---        │
# │            ┆             ┆            ┆            ┆   ┆        ┆          ┆        ┆ str        │
# ╞════════════╪═════════════╪════════════╪════════════╪═══╪════════╪══════════╪════════╪════════════╡
# │ 2011-04-02 ┆ Halmstads   ┆ Kalmar FF  ┆ 0          ┆ … ┆ 2011   ┆ 1        ┆ D      ┆ league     │
# │            ┆ BK          ┆            ┆            ┆   ┆        ┆          ┆        ┆            │
# │ 2011-04-03 ┆ IFK         ┆ GAIS       ┆ 2          ┆ … ┆ 2011   ┆ 1        ┆ H      ┆ league     │
# ...
